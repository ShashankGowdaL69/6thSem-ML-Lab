# %% [markdown]
# <a href="https://colab.research.google.com/github/ShashankGowdaL69/6thSem-ML-Lab/blob/main/Lab10_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Load dataset
df = pd.read_csv('iris.csv')

# Use only 2 features
X = df[['petal_length', 'petal_width']]

# Elbow method
sse = []
k_range = range(1,10)

for k in k_range:
    km = KMeans(n_clusters=k, n_init=10)
    km.fit(X)
    sse.append(km.inertia_)

plt.plot(k_range, sse, marker='o')
plt.xlabel('K')
plt.ylabel('SSE')
plt.title('Elbow Plot')
plt.show()

# Final model (K=3)
km = KMeans(n_clusters=3, n_init=10)
df['cluster'] = km.fit_predict(X)

print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  cluster
# 0           5.1          3.5           1.4          0.2  setosa        1
# 1           4.9          3.0           1.4          0.2  setosa        1
# 2           4.7          3.2           1.3          0.2  setosa        1
# 3           4.6          3.1           1.5          0.2  setosa        1
# 4           5.0          3.6           1.4          0.2  setosa        1
